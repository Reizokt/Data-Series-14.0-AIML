# %% [markdown]
# ### Arahan Assignment
# 0. Gunakan dataset student score
# 1. Lakukan proses Exploratory data analysis
# 2. Lakukan feature engineering :
# - Check Duplicated Data
# - Check Missing Value Handling
# - Outlier Analysis
# 3. Lakukan modelling machine learning regression : gunakan minimal 2 model (linear regression, decision tree regressor, atau random forest regressor)
# 4. Lakukan evaluasi model
# 5. Berikan kesimpulan model mana yang terbaik performanya

# %%
# Import libraries and resources
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 0. Data set student score

# %%
#0. student score data
file_path = '/content/student_scores.csv'
dataset = pd.read_csv(file_path)
dataset.head(10)
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30
# 5    1.5      20
# 6    9.2      88
# 7    5.5      60
# 8    8.3      81
# 9    2.7      25

# %% [markdown]
# 1. Explanatory Data

# %%
#1. explanatory data
dataset.info()

dataset.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Hours   25 non-null     float64
#  1   Scores  25 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 528.0 bytes
#            Hours     Scores
# count  25.000000  25.000000
# mean    5.012000  51.480000
# std     2.525094  25.286887
# min     1.100000  17.000000
# 25%     2.700000  30.000000
# 50%     4.800000  47.000000
# 75%     7.400000  75.000000
# max     9.200000  95.000000

# %%
#score chart
plt.figure(figsize=(12,6))
sns.pairplot(dataset,x_vars=['Hours'],y_vars=['Scores'],size=7,kind='scatter')
plt.xlabel('Hours')
plt.ylabel('Scores')
plt.title('Score chart')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:2100: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# 2. Feature Engineering

# %%
# duplicate data

df = dataset.copy()
print("Data Sebelum Pemeriksaan Duplikat:")
print(df.shape)
duplicate_rows_before = df[df.duplicated()]
duplicate_rows_before
print("\nData Setelah Pemeriksaan Duplikat:")
print(df.shape)
# Out:
# Data Sebelum Pemeriksaan Duplikat:
# (25, 2)
# Empty DataFrame
# Columns: [Hours, Scores]
# Index: []

# %%
#Check missing value
df.isna().sum()
# Out:
# Hours     0
# Scores    0
# dtype: int64

# %%
#outlier analysis

import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(x="Hours", data=df)

plt.xlabel("Hours")
plt.ylabel("Frequency")
plt.title("Boxplot Hours")

plt.show()

# %% [markdown]
# 3. Machine Learning Reggresion

# %%
# Out:
# 0    2.5
# 1    5.1
# 2    3.2
# 3    8.5
# 4    3.5
# Name: Hours, dtype: float64

# %%
# Out:
# 0    21
# 1    47
# 2    27
# 3    75
# 4    30
# Name: Scores, dtype: int64

# %%
# Out:
# 1     5.1
# 22    3.8
# 5     1.5
# 2     3.2
# 12    4.5
# 15    8.9
# 3     8.5
# 4     3.5
# 20    2.7
# 17    1.9
# 21    4.8
# 18    6.1
# 24    7.8
# 7     5.5
# 10    7.7
# 14    1.1
# 19    7.4
# 6     9.2
# Name: Hours, dtype: float64

# %%
# Out:
# 8     8.3
# 16    2.5
# 0     2.5
# 23    6.9
# 11    5.9
# 9     2.7
# 13    3.3
# Name: Hours, dtype: float64

# %% [markdown]
# - Linear Reggresion

# %%
from sklearn.linear_model import LinearRegression

# %%
import numpy as np

X_train = X_train[:, np.newaxis]
X_test = X_test[:, np.newaxis]

X_train
# Out:
# array([[[[[[5.1]]]]],
#
#
#
#
#        [[[[[3.8]]]]],
#
#
#
#
#        [[[[[1.5]]]]],
#
#
#
#
#        [[[[[3.2]]]]],
#
#
#
#
#        [[[[[4.5]]]]],
#
#
#
#
#        [[[[[8.9]]]]],
#
#
#
#
#        [[[[[8.5]]]]],
#
#
#
#
#        [[[[[3.5]]]]],
#
#
#
#
#        [[[[[2.7]]]]],
#
#
#
#
#        [[[[[1.9]]]]],
#
#
#
#
#        [[[[[4.8]]]]],
#
#
#
#
#        [[[[[6.1]]]]],
#
#
#
#
#        [[[[[7.8]]]]],
#
#
#
#
#        [[[[[5.5]]]]],
#
#
#
#
#        [[[[[7.7]]]]],
#
#
#
#
#        [[[[[1.1]]]]],
#
#
#
#
#        [[[[[7.4]]]]],
#
#
#
#
#        [[[[[9.2]]]]]])

# %%
X_test
# Out:
# array([[[[[[8.3]]]]],
#
#
#
#
#        [[[[[2.5]]]]],
#
#
#
#
#        [[[[[2.5]]]]],
#
#
#
#
#        [[[[[6.9]]]]],
#
#
#
#
#        [[[[[5.9]]]]],
#
#
#
#
#        [[[[[2.7]]]]],
#
#
#
#
#        [[[[[3.3]]]]]])

# %%
y_train
# Out:
# 1     47
# 22    35
# 5     20
# 2     27
# 12    41
# 15    95
# 3     75
# 4     30
# 20    30
# 17    24
# 21    54
# 18    67
# 24    86
# 7     60
# 10    85
# 14    17
# 19    69
# 6     88
# Name: Scores, dtype: int64

# %%
y_test
# Out:
# 8     81
# 16    30
# 0     21
# 23    76
# 11    62
# 9     25
# 13    42
# Name: Scores, dtype: int64

# %%
X_train_reshaped = X_train.reshape(X_train.shape[0], -1)
lr_model.fit(X_train_reshaped, y_train)
# Out:
# LinearRegression()

# %%
y_pred_train = lr_model.predict(X_train.reshape(X_train.shape[0], -1))
y_pred_train
# Out:
# array([52.02223727, 39.39391742, 17.05150538, 33.56546211, 46.19378196,
#        88.93578761, 85.05015073, 36.47968977, 28.70841601, 20.93714226,
#        49.10800962, 61.73632947, 78.25028619, 55.90787415, 77.27887697,
#        13.1658685 , 74.36464932, 91.85001526])

# %%
y_train
# Out:
# 1     47
# 22    35
# 5     20
# 2     27
# 12    41
# 15    95
# 3     75
# 4     30
# 20    30
# 17    24
# 21    54
# 18    67
# 24    86
# 7     60
# 10    85
# 14    17
# 19    69
# 6     88
# Name: Scores, dtype: int64

# %%
y_pred = lr_model.predict(X_test.reshape(X_test.shape[0], -1))

# %%
y_pred
# Out:
# array([83.10733229, 26.76559757, 26.76559757, 69.50760322, 59.79351103,
#        28.70841601, 34.53687133])

# %%
c = [i for i in range (1,len(y_test)+1,1)]
plt.plot(c,y_test,color='r',linestyle='-',label='Actual Data')
plt.plot(c,y_pred,color='b',linestyle='dashed',label='Prediction')
plt.xlabel('Scores')
plt.ylabel('index')
plt.title('Prediction with Linear Regression')
plt.legend()
plt.show()

# %%
from sklearn.metrics import r2_score,mean_squared_error

rsq = r2_score(y_test,y_pred)
print('r square Linear Regression:',rsq)
print('Intercept of the Linear Regression model:',lr_model.intercept_)
print('Coefficient of the line Linear Regression:',lr_model.coef_)
# Out:
# r square Linear Regression: 0.9553509219739938
# Intercept of the Linear Regression model: 2.4803670915057623
# Coefficient of the line Linear Regression: [9.71409219]

# %% [markdown]
# - Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor # mahasiswa B

# %%
import pandas as pd
import numpy as np

X_train_reshaped = X_train.reshape(X_train.shape[0], -1)

dt_model = DecisionTreeRegressor()
dt_model.fit(X_train_reshaped, y_train)
# Out:
# DecisionTreeRegressor()

# %%
import pandas as pd
import numpy as np

# Assuming X_test is already loaded
X_test_reshaped = X_test.reshape(X_test.shape[0], -1) # Reshape X_test similar to X_train

y_pred_dt = dt_model.predict(X_test_reshaped)

# %%
y_pred_dt
# Out:
# array([75., 30., 30., 69., 67., 30., 27.])

# %%
y_test
# Out:
# 8     81
# 16    30
# 0     21
# 23    76
# 11    62
# 9     25
# 13    42
# Name: Scores, dtype: int64

# %%
X_test
# Out:
# array([[[[[[8.3]]]]],
#
#
#
#
#        [[[[[2.5]]]]],
#
#
#
#
#        [[[[[2.5]]]]],
#
#
#
#
#        [[[[[6.9]]]]],
#
#
#
#
#        [[[[[5.9]]]]],
#
#
#
#
#        [[[[[2.7]]]]],
#
#
#
#
#        [[[[[3.3]]]]]])

# %%
c = [i for i in range (1,len(y_test)+1,1)]
plt.plot(c,y_test,color='r',linestyle='-',label='Actual Data')
plt.plot(c,y_pred_dt,color='b',linestyle='dashed',label='Prediction')
plt.xlabel('Hours')
plt.ylabel('index')
plt.title('Prediction with Decision Tree')
plt.legend()
plt.show()

# %%
rsq_dt = r2_score(y_test,y_pred_dt)
print('r square Decision Tree Results:',rsq_dt)
# Out:
# r square Decision Tree Results: 0.8803859268443893

# %% [markdown]
# Evaluasi model: Model yang lebih baik adalah decisioon tree dengan 0.880 dibandingkan dengan linear reggresion
